# %%
import numpy as np
from autograd.nn import Linear
from autograd.tensor import Tensor
from utils import draw_dot

# %%
input_dim, output_dim = 2, 3
B = 2
X = Tensor(np.ones((B, input_dim)))
linear1 = Linear(input_dim, output_dim)
linear2 = Linear(output_dim, input_dim)
h = linear1.forward(X)
Y = linear2.forward(h)

# Y.grad
a = Y ** 2

b = 2 ** a

# b.backward()

# target = Tensor(np.ones((B, input_dim)))
# diff = target * 2

# %%
draw_dot(b)
